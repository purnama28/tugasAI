# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#mebuat data dari file csv
df = pd.read_csv('D:/Purnama28/nafld1.csv')

# %%
#menambahkan beberapa baris pertama
print(df.head())
# Out:
#    Unnamed: 0  id  age  male  weight  height        bmi  case.id  futime  \
# 0        3631   1   57     0    60.0   163.0  22.690939  10630.0    6261
# 1        8458   2   67     0    70.4   168.0  24.884028  14817.0     624
# 2        6298   3   53     1   105.8   186.0  30.453537      3.0    1783
# 3       15398   4   56     1   109.3   170.0  37.830100   6628.0    3143
# 4       13261   5   68     1     NaN     NaN        NaN   1871.0    1836
#
#    status
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1

# %%
#mengghitung jumlah nilai yang hilang
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# id               0
# age              0
# male             0
# weight        4786
# height        3168
# bmi           4961
# case.id         31
# futime           0
# status           0
# dtype: int64

# %%
#menghapus baris yang  mengandung  nilai yang hilang
df.dropna(inplace=True)

# %%
# Definisikan fitur dan target
x = df.drop('status',axis=1)
y = df[['status']]

# %%
# Membagi data menjadi train dan test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# Membuat model Decision Tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='gini',random_state=42,max_depth=3,min_samples_leaf=5)

# %%
# Melatih model dengan data pelatihan
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=5, random_state=42)

# %%
# Membuat model Decision Tree
model = DecisionTreeClassifier(random_state=42)

# %%
# Melatih model dengan data pelatihan
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Membuat prediksi dengan data uji
y_pred = model.predict(x_test)

# %%
# Prediksi label untuk data tes
y_pred = model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# Impor fungsi classification_report dari modul sklearn.metrics
from sklearn.metrics import classification_report

# %%
# Impor fungsi confusion_matrix dari modul sklearn.metrics
from sklearn.metrics import confusion_matrix

# %%
# Evaluasi model
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print('Classification Report:')
print(classification_report(y_test, y_pred))
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.8838042180660565
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94      2317
#            1       0.27      0.29      0.28       196
#
#     accuracy                           0.88      2513
#    macro avg       0.61      0.61      0.61      2513
# weighted avg       0.89      0.88      0.89      2513
#
# Confusion Matrix:
# [[2164  153]
#  [ 139   57]]

# %%
target=list(df['status'].unique())
feature_names=list(x.columns)

# %%
#tambakan comen pada program berikutt
from sklearn.tree import export_text

# %%
# Membuat representasi teks dari model menggunakan fungsi export_text
r=export_text(model,feature_names=feature_names)
print(r)
# Out:
# |--- age <= 77.50
# |   |--- age <= 66.50
# |   |   |--- futime <= 557.50
# |   |   |   |--- Unnamed: 0 <= 742.50
# |   |   |   |   |--- age <= 65.50
# |   |   |   |   |   |--- bmi <= 39.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- bmi >  39.00
# |   |   |   |   |   |   |--- weight <= 138.30
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- weight >  138.30
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age >  65.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- Unnamed: 0 >  742.50
# |   |   |   |   |--- age <= 53.50
# |   |   |   |   |   |--- Unnamed: 0 <= 2740.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Unnamed: 0 >  2740.50
# |   |   |   |   |   |   |--- weight <= 151.70
# |   |   |   |   |   |   |   |--- weight <= 46.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- weight >  46.00
# |   |   |   |   |   |   |   |   |--- case.id <= 114.00
# ...

# %%
# Impor modul tree dari sklearn untuk mengakses fungsi plot_tree
from sklearn import tree

# %%
# Menampilkan Decision Tree
plt.figure(figsize=(20,10))
tree.plot_tree(model)
plt.show()
